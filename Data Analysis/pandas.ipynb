# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# what you need to learn
# - loading data
# - selection
#     - rows
#     - columns
# - manipulation
#     - add columns
#     - remove columns
#     - rename columns
#     - change data type
#     - delete data
#     - remove duplicates
#     - sort
#     - group by
#     - pivot
#     - merge
# - visualisation
#     - line plot
#     - bar plot
#     - histogram
#     - box plot
#     - scatter plot
#     - heatmap
#     - pie chart
#     - word cloud

# %%
penguins=sns.load_dataset('penguins')
penguins

# %% [markdown]
# - analysis
#     - univariate analysis
#     - bi variate analysis
#     - multivariate analysis

# %% [markdown]
# - loading data
#     - excel file
#     - custom data in a varaible
#     - csv/json/etc
#     - database(sql)

# %%
student={
    'Name':['vaibhav','siya','aman','amjad','sneha','aditi','bhupendra'],
    'College':['srmcem','srmcem','kmc','kmc','cu','srmcem','srmcem'],
    'DOB':['25jan','2 feb','2 apr','16 aug','16 sep','17 dec','22 may']
}

sdf=pd.DataFrame(student)
sdf

# %%
data=pd.read_excel('C:/Users/pc/OneDrive/Desktop/Book1.xlsx')
data

# %%
data.info()

# %%
data.columns.tolist()

# %%
data['item']        #column selection as dictionary key

# %%
data.amount       #single columns   #column selection as object attribute

# %%
#syntax to select two columns 
#data[column list]
data[['item','qty']]

# %% [markdown]
# oprn btween column(numeric)

# %% [markdown]
# adding columns

# %%
data['total']=data['amount']*data['qty']

# %%
data

# %%
data['new']='some crap'
data

# %% [markdown]
# removing columns

# %%
data.drop(columns=['new'],inplace=True)
data

# %%
data.iloc[0] #index lock

# %%
data.iloc[:2]

# %%
data.drop(index=[0,2])

# %%
data

# %%
sdf

# %%
sdf.drop(index=[5,6])

# %%
data['qty']-1

# %%
data['qty']=data['qty']-1

# %%
#rename
data.rename(
    mapper={'item':'product'},axis=1,inplace=True
)
data

# %% [markdown]
# 23-oct-2023
# Operations
# - change data type
# - delete data
#     >columns
#     >indexes
# - remove duplicates
# - sort
# - group by
# - pivot
# - merge

# %%
penguins.columns.tolist()

# %%
penguins.drop(columns="body_mass_g") #temporary data remove for permanent we have to use inplace true

# %%
penguins.drop(columns=["island","flipper_length_mm"])

# %%
penguins.drop(index=2) #drop row third

# %%
penguins.drop(index=[0,1,2,3,4])  #drop the five rows
print(penguins)

# %%
penguins.drop(index=range(10)) #drop 10 rows

# %%
np.nan

# %%
penguins

# %%
penguins.isnull()

# %%
penguins.isnull().sum()

# %%
sns.heatmap(penguins.isnull(), cbar=False) #overall null value visulaisation

# %%
penguins.isnull().sum().plot(kind='bar') #column wise null value visalisation

# %% [markdown]
# removing null values(nan values)

# %%
penguins.dropna()

# %%
penguins.shape

# %%
penguins.dropna().shape

# %%
penguins.dropna(inplace=True)
print(penguins.shape)

# %%
penguins.drop_duplicates(subset=['species'])

# %%
penguins.sort_values(by='sex',ascending=False)

# %%
penguins.sort_values(by=['species','sex','island'])

# %%
penguins.sort_index(ascending=False)

# %% [markdown]
# #data types in pandas
# - int
# - float
# - boolean
# - datetime
# - object(if datatype not understand by pandas then object is used)
# - string()
# - category

# %%
penguins.info

# %%
penguins.dtypes

# %%
penguins.select_dtypes(include='number')

# %%
penguins.select_dtypes(include='object')

# %%
penguins.select_dtypes(exclude='number')

# %% [markdown]
# change the data types of columns

# %%
penguins['island'].astype('category') #not actual applied in the columns

# %%
penguins.dtypes

# %%
penguins.sex=penguins.sex.astype('bool')
penguins.head()

# %% [markdown]
# simple visualisation -univariate
# - for numerical data
#     - line plot -> .plot()
#     - bar plot -> .plot(kind='bar')
#     - box plate -> .plot(kind='box')
#     - area plate -> .plot(kind='area')
#     - hsitogram -> .hist()
#     - scatter plot -> .scatter()
# - for categoriacal data
#     -
#     -

# %%
penguins['bill_depth_mm'].hist()

# %%
penguins['bill_depth_mm'].plot(figsize=(15,5))

# %%
penguins['bill_depth_mm'].plot(kind='area',figsize=(15,5))

# %%
penguins['bill_depth_mm'].plot(kind='box',figsize=(15,5))

# %%
penguins.columns

# %%
penguins['bill_depth_mm'].plot(kind='box',figsize=(5,2),vert=True)

# %%
penguins['island'].value_counts()

# %%
penguins['island'].value_counts().plot(kind='bar')

# %% [markdown]
# compare univariate data in singe graph

# %%
penguins[['bill_depth_mm','bill_length_mm']].plot()

# %%
penguins[['bill_depth_mm','bill_length_mm']].plot(kind='box',figsize=(15,5))

# %%
penguins[['bill_depth_mm','bill_length_mm']].hist(bins=20,figsize=(15,5))

# %% [markdown]
# putting columns visualisation in subplots

# %%
penguins[['bill_depth_mm','bill_length_mm']].plot(layout=(1,2),subplots=True,figsize=(15,5))

# %% [markdown]
# power of seaborn -better visualisation

# %%
sns.displot(data=penguins,x='bill_depth_mm')

# %%
sns.displot(data=penguins,x='bill_depth_mm',hue='island')

# %%
sns.displot(data=penguins,x='body_mass_g',hue='island')

# %%
sns.countplot(data=penguins,x='island')

# %%
sns.countplot(data=penguins,x='island',hue='species')

# %% [markdown]
# bivariate analysis
# - scatter plot
# - violin plot(alt to box plot)
# - pair plot

# %%
sns.scatterplot(data=penguins,x='bill_length_mm',y="bill_depth_mm")
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %%
sns.scatterplot(data=penguins,x='bill_length_mm',y="bill_depth_mm",hue='species')
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %%
sns.scatterplot(data=penguins,x='bill_length_mm',y="bill_depth_mm",hue='island')
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %%
sns.scatterplot(data=penguins,x='bill_length_mm',y="bill_depth_mm",hue="flipper_length_mm")
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %%
sns.color_palette()
# Out:
# [(0.12156862745098039, 0.4666666666666667, 0.7058823529411765),
#  (1.0, 0.4980392156862745, 0.054901960784313725),
#  (0.17254901960784313, 0.6274509803921569, 0.17254901960784313),
#  (0.8392156862745098, 0.15294117647058825, 0.1568627450980392),
#  (0.5803921568627451, 0.403921568627451, 0.7411764705882353),
#  (0.5490196078431373, 0.33725490196078434, 0.29411764705882354),
#  (0.8901960784313725, 0.4666666666666667, 0.7607843137254902),
#  (0.4980392156862745, 0.4980392156862745, 0.4980392156862745),
#  (0.7372549019607844, 0.7411764705882353, 0.13333333333333333),
#  (0.09019607843137255, 0.7450980392156863, 0.8117647058823529)]

# %%
sns.set_palette('cool')

# %%
sns.scatterplot(data=penguins,x='bill_length_mm',y="bill_depth_mm",hue="island")
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %%
sns.scatterplot(data=penguins,x='bill_length_mm',y="bill_depth_mm",hue="flipper_length_mm",
                palette='warm')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\pc\miniconda3\Lib\site-packages\seaborn\palettes.py:235, in color_palette(palette, n_colors, desat, as_cmap)
#     233 try:
#     234     # Perhaps a named matplotlib colormap?
# --> 235     palette = mpl_palette(palette, n_colors, as_cmap=as_cmap)
#     236 except (ValueError, KeyError):  # Error class changed in mpl36
#
# File c:\Users\pc\miniconda3\Lib\site-packages\seaborn\palettes.py:406, in mpl_palette(name, n_colors, as_cmap)
#     405 else:
# --> 406     cmap = get_colormap(name)
#     408 if name in MPL_QUAL_PALS:
#
# File c:\Users\pc\miniconda3\Lib\site-packages\seaborn\_compat.py:133, in get_colormap(name)
#     132 try:
# --> 133     return mpl.colormaps[name]
#     134 except AttributeError:
#
# ...

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.set_palette('rainbow')

# %%
tips = sns.load_dataset("tips")
sns.relplot(data=tips, x="total_bill", y="tip")
sns.relplot(data=tips, x="total_bill", y="tip",hue='smoker')
sns.relplot(data=tips, x="total_bill", y="tip",hue='sex')

# %%
sns.relplot(data=tips, x="total_bill", y="tip",hue='smoker',style='time')

# %%
sns.relplot(
    data=tips, x="total_bill", y="tip", hue="size",
)


sns.relplot(
    data=tips,
    x="total_bill", y="tip",
    hue="size", palette="ch:r=-.5,l=.75"
)

# %%
sns.relplot(data=tips, x="total_bill", y="tip", size="size")

# %%
sns.relplot(
    data=tips, x="total_bill", y="tip",
    size="size", sizes=(15, 100),style='size'
)

# %%
dowjones = sns.load_dataset("dowjones")
sns.relplot(data=dowjones, x="Date", y="Price", kind="line")

# %%
sns.lineplot(data=dowjones, x="Date", y="Price")
# Out:
# <Axes: xlabel='Date', ylabel='Price'>
